# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\mahen\Data Analytics\Netflix TV Shows and Movies.csv")
df
# Out:
#       index         id                               title   type  \
# 0         0    tm84618                         Taxi Driver  MOVIE
# 1         1   tm127384     Monty Python and the Holy Grail  MOVIE
# 2         2    tm70993                       Life of Brian  MOVIE
# 3         3   tm190788                        The Exorcist  MOVIE
# 4         4    ts22164        Monty Python's Flying Circus   SHOW
# ...     ...        ...                                 ...    ...
# 5278   5278  tm1040816         Momshies! Your Soul is Mine  MOVIE
# 5279   5279  tm1014599                           Fine Wine  MOVIE
# 5280   5280  tm1045018                               Clash  MOVIE
# 5281   5281  tm1098060                      Shadow Parties  MOVIE
# 5282   5282   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %%
df.head()
# Out:
#    index        id                            title   type  \
# 0      0   tm84618                      Taxi Driver  MOVIE
# 1      1  tm127384  Monty Python and the Holy Grail  MOVIE
# 2      2   tm70993                    Life of Brian  MOVIE
# 3      3  tm190788                     The Exorcist  MOVIE
# 4      4   ts22164     Monty Python's Flying Circus   SHOW
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  King Arthur, accompanied by his squire, recrui...          1975
# 2  Brian Cohen is an average young Jewish man, bu...          1979
# 3  12-year-old Regan MacNeil begins to adapt an e...          1973
# 4  A British sketch comedy series with the shows ...          1969
#
#   age_certification  runtime    imdb_id  imdb_score  imdb_votes
# 0                 R      113  tt0075314         8.3    795222.0
# 1                PG       91  tt0071853         8.2    530877.0
# ...

# %%
df.tail()
# Out:
#       index         id                               title   type  \
# 5278   5278  tm1040816         Momshies! Your Soul is Mine  MOVIE
# 5279   5279  tm1014599                           Fine Wine  MOVIE
# 5280   5280  tm1045018                               Clash  MOVIE
# 5281   5281  tm1098060                      Shadow Parties  MOVIE
# 5282   5282   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 5278  Three women with totally different lives accid...          2021
# 5279  A beautiful love story that can happen between...          2021
# 5280  A man from Nigeria returns to his family in Ca...          2021
# 5281  A family faces destruction in a long-running c...          2021
# 5282  With winter behind them, Bheem and his townspe...          2021
#
#      age_certification  runtime     imdb_id  imdb_score  imdb_votes
# 5278               NaN      108  tt14412240         5.8        26.0
# ...

# %%
df.shape
# Out:
# (5283, 11)

# %%
df.columns.tolist()
# Out:
# ['index',
#  'id',
#  'title',
#  'type',
#  'description',
#  'release_year',
#  'age_certification',
#  'runtime',
#  'imdb_id',
#  'imdb_score',
#  'imdb_votes']

# %%
df["index"].unique()
# Out:
# array([   0,    1,    2, ..., 5280, 5281, 5282], dtype=int64)

# %%
df["index"].nunique()
# Out:
# 5283

# %%
df["id"].unique()
# Out:
# array(['tm84618', 'tm127384', 'tm70993', ..., 'tm1045018', 'tm1098060',
#        'ts271048'], dtype=object)

# %%
df["id"].nunique()
# Out:
# 5283

# %%
df["title"].unique()
# Out:
# array(['Taxi Driver', 'Monty Python and the Holy Grail', 'Life of Brian',
#        ..., 'Clash', 'Shadow Parties',
#        'Mighty Little Bheem: Kite Festival'], dtype=object)

# %%
df["title"].nunique()
# Out:
# 5237

# %%
df["title"].mode()
# Out:
# 0    The Gift
# Name: title, dtype: object

# %%
df["title"].value_counts()
# Out:
# title
# The Gift                              3
# Taxi Driver                           2
# Time Out                              2
# Love O2O                              2
# U Turn                                2
#                                      ..
# Safe                                  1
# The End of the F***ing World          1
# One Day at a Time                     1
# The Bureau of Magical Things          1
# Mighty Little Bheem: Kite Festival    1
# Name: count, Length: 5237, dtype: int64

# %%
df["type"].unique()
# Out:
# array(['MOVIE', 'SHOW'], dtype=object)

# %%
df['type'].value_counts()
# Out:
# type
# MOVIE    3407
# SHOW     1876
# Name: count, dtype: int64

# %%
df["description"].unique()
# Out:
# array(['A mentally unstable Vietnam War veteran works as a night-time taxi driver in New York City where the perceived decadence and sleaze feed his urge for violent action, attempting to save a preadolescent prostitute in the process.',
#        'King Arthur, accompanied by his squire, recruits his Knights of the Round Table, including Sir Bedevere the Wise, Sir Lancelot the Brave, Sir Robin the Not-Quite-So-Brave-As-Sir-Lancelot and Sir Galahad the Pure. On the way, Arthur battles the Black Knight who, despite having had all his limbs chopped off, insists he can still fight. They reach Camelot, but Arthur decides not  to enter, as "it is a silly place".',
# ...

# %%
df["description"].nunique()
# Out:
# 5276

# %%
df["release_year"].unique()
# Out:
# array([1976, 1975, 1979, 1973, 1969, 1971, 1964, 1980, 1967, 1966, 1961,
#        1954, 1958, 1968, 1977, 1972, 1963, 1960, 1956, 1953, 1974, 1959,
#        1962, 1978, 1986, 1989, 1984, 1990, 1987, 1983, 1982, 1981, 1988,
#        1985, 1995, 2000, 1997, 1994, 1996, 1999, 1998, 1993, 1992, 1991,
#        2008, 2010, 2004, 2005, 2003, 2009, 2007, 2006, 2001, 2002, 2012,
#        2011, 2014, 2013, 2015, 2016, 2017, 2018, 2019, 2020, 2022, 2021],
#       dtype=int64)

# %%
df["release_year"].value_counts()
# Out:
# release_year
# 2019    749
# 2018    733
# 2021    687
# 2020    657
# 2017    555
#        ...
# 1974      1
# 1959      1
# 1962      1
# 1978      1
# 1985      1
# Name: count, Length: 66, dtype: int64

# %%
df["release_year"].nunique()
# Out:
# 66

# %%
df["release_year"].mode()
# Out:
# 0    2019
# Name: release_year, dtype: int64

# %%
df['age_certification'].unique()
# Out:
# array(['R', 'PG', 'TV-14', 'G', 'PG-13', nan, 'TV-MA', 'TV-PG', 'TV-Y',
#        'TV-G', 'TV-Y7', 'NC-17'], dtype=object)

# %%
df['age_certification'].value_counts()
# Out:
# age_certification
# TV-MA    792
# R        548
# TV-14    436
# PG-13    424
# PG       238
# TV-PG    172
# G        105
# TV-Y7    104
# TV-Y      94
# TV-G      72
# NC-17     13
# Name: count, dtype: int64

# %%
df['age_certification'].nunique()
# Out:
# 11

# %%
df['runtime'].unique()
# Out:
# array([113,  91,  94, 133,  30, 102, 170, 104, 110, 117, 158, 100,  78,
#         99, 115,  77,  68, 150,  97, 186, 120, 105, 235, 161,  43, 124,
#        152, 162,  74,  93, 153, 142, 138, 163, 135, 141, 131,  24,  89,
#        229,  96, 116,  90,  51,  10, 127, 103,  23,  84,  26,  15,  50,
#         87, 144, 174,  72, 134, 172, 148, 160, 108, 159, 129, 151, 107,
#         48,  44,  22,  92, 169,  25,  47,  40, 106,  46, 119, 126, 130,
#        136, 123, 165, 112, 128, 118, 101,  88,  28,  95, 114,  21,  19,
#         75,  63, 185,   9, 171, 156, 177, 175, 155, 206, 145, 180,  55,
#        146,  58,  59,  56, 149, 147,  49,  57,  45, 111,  98, 139,  42,
#        121, 125, 143, 140, 122, 154, 109,  81,  82,  52,  83,  29,  27,
#         64, 132,   7, 224,  11,  86,   6,  35,  18,  61,  14,  17, 210,
#         76, 213,  71,  20,  85,  12,   0, 137, 183, 178,  60, 157, 189,
#          3, 225, 193, 166, 179,  67, 173, 167,  80,  73,  37, 192,  69,
# ...

# %%
df['runtime'].nunique()
# Out:
# 197

# %%
df['runtime'].value_counts()
# Out:
# runtime
# 90     119
# 24     113
# 100    100
# 95     100
# 45      98
#       ...
# 183      1
# 225      1
# 193      1
# 173      1
# 176      1
# Name: count, Length: 197, dtype: int64

# %%
df['imdb_id'].unique()
# Out:
# array(['tt0075314', 'tt0071853', 'tt0079470', ..., 'tt14620732',
#        'tt10168094', 'tt13711094'], dtype=object)

# %%
df['imdb_id'].nunique()
# Out:
# 5283

# %%
df['imdb_score'].unique()
# Out:
# array([8.3, 8.2, 8. , 8.1, 8.8, 7.7, 7.8, 5.8, 7.3, 7.5, 7.6, 6.9, 7.2,
#        6.2, 6.4, 6.7, 6.8, 9. , 2.1, 7.4, 6.5, 4.6, 4.2, 5.1, 8.9, 6.6,
#        7.1, 4.9, 6.1, 6. , 7.9, 7. , 5.6, 8.7, 6.3, 4.8, 3.8, 5.2, 5.4,
#        8.4, 8.6, 8.5, 4.5, 5.7, 5.9, 4.7, 4. , 5.5, 3.6, 5. , 9.5, 9.3,
#        3.9, 5.3, 4.1, 4.4, 2.9, 4.3, 3.5, 9.6, 3.4, 3.3, 2. , 3.2, 1.7,
#        2.6, 9.2, 3.1, 3.7, 1.9, 2.8, 2.7, 1.5, 2.3, 3. , 2.2, 9.1, 2.5,
#        2.4, 1.6, 1.8])

# %%
df['imdb_score'].nunique()
# Out:
# 81

# %%
df['imdb_score'].value_counts()
# Out:
# imdb_score
# 6.6    201
# 6.8    199
# 6.5    193
# 6.2    192
# 7.4    190
#       ...
# 2.0      1
# 1.9      1
# 2.4      1
# 1.6      1
# 1.8      1
# Name: count, Length: 81, dtype: int64

# %%
df['imdb_votes'].unique()
# Out:
# array([7.95222e+05, 5.30877e+05, 3.92419e+05, ..., 7.02000e+02,
#        8.53000e+02, 1.04180e+04])

# %%
df['imdb_votes'].value_counts()
# Out:
# imdb_votes
# 43.0        11
# 25.0        11
# 30.0         9
# 14.0         9
# 74.0         9
#             ..
# 103.0        1
# 399.0        1
# 278223.0     1
# 28718.0      1
# 10418.0      1
# Name: count, Length: 3831, dtype: int64

# %%
df['imdb_votes'].nunique()
# Out:
# 3831

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5283 non-null   int64
#  1   id                 5283 non-null   object
#  2   title              5283 non-null   object
#  3   type               5283 non-null   object
#  4   description        5278 non-null   object
#  5   release_year       5283 non-null   int64
#  6   age_certification  2998 non-null   object
#  7   runtime            5283 non-null   int64
#  8   imdb_id            5283 non-null   object
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5267 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 454.1+ KB

# %%
df.isnull().sum()
# Out:
# index                   0
# id                      0
# title                   0
# type                    0
# description             5
# release_year            0
# age_certification    2285
# runtime                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes             16
# dtype: int64

# %%
continous=["release_year"]
count=["runtime","imdb_score","imdb_votes"]
categorical=["title","type","description","imdb_id"]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["release_year"].describe()
# Out:
# count    5283.000000
# mean     2015.879992
# std         7.346098
# min      1953.000000
# 25%      2015.000000
# 50%      2018.000000
# 75%      2020.000000
# max      2022.000000
# Name: release_year, dtype: float64

# %%
df["runtime"].describe()
# Out:
# count    5283.000000
# mean       79.199886
# std        38.915974
# min         0.000000
# 25%        45.000000
# 50%        87.000000
# 75%       106.000000
# max       235.000000
# Name: runtime, dtype: float64

# %%
df["imdb_score"].describe()
# Out:
# count    5283.000000
# mean        6.533447
# std         1.160932
# min         1.500000
# 25%         5.800000
# 50%         6.600000
# 75%         7.400000
# max         9.600000
# Name: imdb_score, dtype: float64

# %%
df.isnull().sum()
# Out:
# index                   0
# id                      0
# title                   0
# type                    0
# description             5
# release_year            0
# age_certification    2285
# runtime                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes             16
# dtype: int64

# %%
sns.boxplot(df['imdb_votes'])
plt.show()

# %%
df[continous].skew()
# Out:
# release_year   -3.429978
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# --> DATA CLEANING
# -------------------

# %%
df["description"] = df["description"].fillna(df["description"].mode()[0])

df["imdb_votes"] = df["imdb_votes"].fillna(df["imdb_votes"].mode()[0])

df["age_certification"] = df["age_certification"].fillna(df["age_certification"].mode()[0])

# %%
df.isnull().sum()
# Out:
# index                0
# id                   0
# title                0
# type                 0
# description          0
# release_year         0
# age_certification    0
# runtime              0
# imdb_id              0
# imdb_score           0
# imdb_votes           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5283 non-null   int64
#  1   id                 5283 non-null   object
#  2   title              5283 non-null   object
#  3   type               5283 non-null   object
#  4   description        5283 non-null   object
#  5   release_year       5283 non-null   int64
#  6   age_certification  5283 non-null   object
#  7   runtime            5283 non-null   int64
#  8   imdb_id            5283 non-null   object
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5283 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 454.1+ KB

# %%
df[count].skew()
# Out:
# runtime        0.129853
# imdb_score    -0.659896
# imdb_votes    11.321678
# dtype: float64

# %%
df["imdb_votes"]=np.log1p(df["imdb_votes"])
df["imdb_votes"]
# Out:
# 0       13.586378
# 1       13.182288
# 2       12.880088
# 3       12.878872
# 4       11.196789
#           ...
# 5278     3.295837
# 5279     3.688879
# 5280     3.496508
# 5281     2.302585
# 5282     2.833213
# Name: imdb_votes, Length: 5283, dtype: float64

# %%
df[count].skew()
# Out:
# runtime       0.129853
# imdb_score   -0.659896
# imdb_votes    0.046842
# dtype: float64

# %%
df.to_excel("cleaned_data.xlsx",index=False)

# %% [markdown]
# LOAD THE DATA
# -------------

# %%
df=pd.read_excel("cleaned_data.xlsx")
df
# Out:
#       index         id                               title   type  \
# 0         0    tm84618                         Taxi Driver  MOVIE
# 1         1   tm127384     Monty Python and the Holy Grail  MOVIE
# 2         2    tm70993                       Life of Brian  MOVIE
# 3         3   tm190788                        The Exorcist  MOVIE
# 4         4    ts22164        Monty Python's Flying Circus   SHOW
# ...     ...        ...                                 ...    ...
# 5278   5278  tm1040816         Momshies! Your Soul is Mine  MOVIE
# 5279   5279  tm1014599                           Fine Wine  MOVIE
# 5280   5280  tm1045018                               Clash  MOVIE
# 5281   5281  tm1098060                      Shadow Parties  MOVIE
# 5282   5282   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %% [markdown]
#  DATA ANALYSIS
# --------------

# %% [markdown]
# - MEASURES + PLOTS
# - UNIVARIATE,BIVARIATE,MULTIVARIATE

# %%
continous=["release_year"]
discrete=["imdb_score","imdb_votes",'runtime']
categorical=["title","type","description","imdb_id"]

# %%
 for i in continous:
     print(df[i].describe())
# Out:
# count    5283.000000
# mean     2015.879992
# std         7.346098
# min      1953.000000
# 25%      2015.000000
# 50%      2018.000000
# 75%      2020.000000
# max      2022.000000
# Name: release_year, dtype: float64

# %%
df[continous].describe()
# Out:
#        release_year
# count   5283.000000
# mean    2015.879992
# std        7.346098
# min     1953.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2020.000000
# max     2022.000000

# %%
df[categorical].describe()
# Out:
#            title   type                                        description  \
# count       5283   5283                                               5283
# unique      5237      2                                               5276
# top     The Gift  MOVIE  Away from school, during the winter holidays, ...
# freq           3   3407                                                  7
#
#           imdb_id
# count        5283
# unique       5283
# top     tt0075314
# freq            1

# %%
for i in categorical:
    print(df[i].value_counts(),"\n")
# Out:
# title
# The Gift                              3
# Taxi Driver                           2
# Time Out                              2
# Love O2O                              2
# U Turn                                2
#                                      ..
# Safe                                  1
# The End of the F***ing World          1
# One Day at a Time                     1
# The Bureau of Magical Things          1
# Mighty Little Bheem: Kite Festival    1
# Name: count, Length: 5237, dtype: int64
#
# type
# MOVIE    3407
# SHOW     1876
# Name: count, dtype: int64
#
# description
# Away from school, during the winter holidays, three new stories take place while the Las Encinas students celebrate Christmas.                                                                                                                                                                                      7
# ...

# %%
for i in continous:
    sns.histplot(df[i])
    plt.show()

# %%
df[continous].cov()
# Out:
#               release_year
# release_year     53.965149

# %%
df[continous].corr()
# Out:
#               release_year
# release_year           1.0

# %%
continous=["release_year"]
discrete=["imdb_score","imdb_votes",'runtime']
categorical=["title","type","description","imdb_id"]

# %% [markdown]
# UNIVARIATE PLOT'S
# -----------------

# %%
sns.boxplot(y=df["release_year"],)
plt.show()

# %% [markdown]
# bivariate
# ----------
# ---------

# %%
sns.scatterplot(x=df["release_year"],y=df["runtime"])
plt.show()

# %%
sns.relplot(x=df["release_year"],y=df["runtime"])
plt.show()

# %%
sns.relplot(x=df["release_year"],y=df["runtime"],data=df,hue="type")
plt.show()

# %%
sns.lineplot(x="release_year",y="runtime",data=df)
plt.show()

# %%
sns.pairplot(df,vars=count)
plt.show()

# %%
plt.plot(df["release_year"],marker="*")
plt.show()

# %%
a=df[["release_year","runtime"]].corr()
a
# Out:
#               release_year   runtime
# release_year      1.000000 -0.201491
# runtime          -0.201491  1.000000

# %%
sns.heatmap(a,annot=True)
plt.show()

# %% [markdown]
# plots for discrete data
# -----------------------

# %%
#univariate
df["type"].value_counts()
# Out:
# type
# MOVIE    3407
# SHOW     1876
# Name: count, dtype: int64

# %%
sns.countplot(x=df["type"])
plt.show()

# %%
continous=["release_year"]
discrete=["imdb_score","imdb_votes",'runtime']
categorical=["title","type","description","imdb_id"]

# %%
sns.catplot(x="type",y="release_year",data=df)
plt.show()

# %%
sns.catplot(x="type",y="release_year",data=df,kind="bar")
plt.show()

# %%
sns.boxplot(x="type",y="release_year",data=df)
plt.show()

# %%
plt.pie(x=df["type"].value_counts(),labels=df["type"].value_counts().index,autopct="%0.1f%%",explode=[0.1,0])
plt.show()
